# %% [markdown]
# <a href="https://colab.research.google.com/github/Imran2205/uwsnet/blob/main/colab_notebooks/uw_sem_seg_mask2former_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install gdown

# %%
# download sem seg dataset from google drive and extract it
! gdown https://drive.google.com/uc?id=1OUw-wFBKCHZiOuVehkOREVP6MTzxKBz9
! unzip -q uw_sem_seg_dataset.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OUw-wFBKCHZiOuVehkOREVP6MTzxKBz9
# To: /content/uw_sem_seg_dataset.zip
# 100% 571M/571M [00:07<00:00, 78.9MB/s]

# %%
! rm -rf /content/__MACOSX
! rm -rf /content/uw_sem_seg_dataset.zip

# %%
! gdown https://drive.google.com/uc?id=1B4Xh2rhIGe8oMQtOd2znNsc3oIb32lu8
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1B4Xh2rhIGe8oMQtOd2znNsc3oIb32lu8
# To: /content/hrnetv2_w48_imagenet_pretrained.pth
# 100% 311M/311M [00:04<00:00, 71.1MB/s]

# %%
! pip install imagecodecs
! pip install pickle5
! pip install timm
! pip install tensorboardX
! pip install yacs
! pip install cython
! pip install scipy
! pip install shapely
! pip install timm
! pip install h5py
! pip install submitit
! pip install scikit-image
! python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255335 sha256=8ede44fa26bfff2f7441cb4202efd002318de5b66f36323d1238ed6495b3bd8b
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 19.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 9.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
# ...

# %%
import gdown

gdown.download_folder('https://drive.google.com/drive/folders/1zSUHCpCS02UwisW_lQsNW98MvXDCul1l')
# Out:
# Retrieving folder list
# Processing file 1sROD6FkZ82xR_JbER7Qg68BappRQzUYb model_final.pth
# Building directory structure completed
# Retrieving folder list completed
# Building directory structure
# Downloading...
# From: https://drive.google.com/uc?id=1sROD6FkZ82xR_JbER7Qg68BappRQzUYb
# To: /content/Mask2Former/model_final.pth
# 100%|██████████| 528M/528M [00:08<00:00, 60.8MB/s]
# Download completed
# ['/content/Mask2Former/model_final.pth']

# %%
![[ -d ./Mask2Former-mod ]] && rm -rf ./Mask2Former-mod
# !git clone https://github.com/Imran2205/Mask2Former-mod
# Out:
# Cloning into 'Mask2Former-mod'...
# remote: Enumerating objects: 544, done.
# remote: Counting objects: 100% (544/544), done.
# remote: Compressing objects: 100% (345/345), done.
# remote: Total 544 (delta 316), reused 410 (delta 182), pack-reused 0
# Receiving objects: 100% (544/544), 417.65 KiB | 3.03 MiB/s, done.
# Resolving deltas: 100% (316/316), done.

# %%
! cd ./Mask2Former-mod/mask2former/modeling/pixel_decoder/ops && sh make.sh
# Out:
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-cpython-310
# creating build/lib.linux-x86_64-cpython-310/modules
# copying modules/__init__.py -> build/lib.linux-x86_64-cpython-310/modules
# copying modules/ms_deform_attn.py -> build/lib.linux-x86_64-cpython-310/modules
# creating build/lib.linux-x86_64-cpython-310/functions
# copying functions/__init__.py -> build/lib.linux-x86_64-cpython-310/functions
# copying functions/ms_deform_attn_func.py -> build/lib.linux-x86_64-cpython-310/functions
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# ...

# %%
! find ./uw_sem_seg_dataset -name "._*" -delete

# %%
! python3 ./Mask2Former-mod/train_net.py --num-gpus 1 --config-file \
    ./Mask2Former-mod/configs/uws/semantic-segmentation/maskformer2_R50_bs16_300k.yaml \
    --eval-only MODEL.WEIGHTS /content/Mask2Former/model_final.pth
# Out:
# Command Line Args: Namespace(config_file='./Mask2Former-mod/configs/uws/semantic-segmentation/maskformer2_R50_bs16_300k.yaml', resume=False, eval_only=True, num_gpus=1, num_machines=1, machine_rank=0, dist_url='tcp://127.0.0.1:49152', opts=['MODEL.WEIGHTS', '/content/Mask2Former/model_final.pth'])
# Loading config ./Mask2Former-mod/configs/uws/semantic-segmentation/Base-uws-SemanticSegmentation.yaml with yaml.unsafe_load. Your machine may be at risk if the file contains malicious content.
# [07/24 21:21:20 detectron2]: Rank of current process: 0. World size: 1
# [07/24 21:21:21 detectron2]: Environment info:
# -------------------------------  -----------------------------------------------------------------
# sys.platform                     linux
# Python                           3.10.6 (main, May 29 2023, 11:10:38) [GCC 11.3.0]
# numpy                            1.22.4
# detectron2                       0.6 @/usr/local/lib/python3.10/dist-packages/detectron2
# ...

# %%
import torch

res = torch.load('/content/output/inference/sem_seg_evaluation.pth')

for key in res.keys():
    if key.startswith('IoU'):
        print(key, ': ', res[key])
# Out:
# IoU-crab :  64.89013058675867
# IoU-crocodile :  87.88588708337487
# IoU-dolphin :  67.99680015058115
# IoU-frog :  73.45445437488813
# IoU-nettles :  18.19259463936838
# IoU-octopus :  43.15361539596413
# IoU-otter :  54.50024156648763
# IoU-penguin :  76.70285224893169
# IoU-polar_bear :  91.84357570555588
# IoU-sea_anemone :  20.034052075136913
# IoU-sea_urchin :  56.67828852799951
# IoU-seahorse :  24.156769596199528
# IoU-seal :  53.939345479467704
# IoU-shark :  64.26468922720856
# IoU-shrimp :  67.89639704921964
# IoU-star_fish :  94.81637614330415
# IoU-stingray :  92.65740543012592
# IoU-squid :  61.25194652611749
# IoU-turtle :  92.59966299979523
# IoU-whale :  72.09818795210646
# IoU-nudibranch :  80.18980794191334
# IoU-coral :  47.86475122388222
# IoU-rock :  43.68838718189509
# IoU-water :  89.03709766823617
# IoU-sand :  56.601740467567375
# IoU-plant :  11.613202173233695
# IoU-human :  45.409488941959935
# IoU-reef :  10.243798426420566
# ...
