# %% [markdown]
# <a href="https://colab.research.google.com/github/Imran2205/uwsnet/blob/main/colab_notebooks/uw_sem_seg_hrnet_v2_inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install gdown

# %%
# download sem seg dataset from google drive and extract it
! gdown https://drive.google.com/uc?id=1OUw-wFBKCHZiOuVehkOREVP6MTzxKBz9
! unzip -q uw_sem_seg_dataset.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1OUw-wFBKCHZiOuVehkOREVP6MTzxKBz9
# To: /content/uw_sem_seg_dataset.zip
# 100% 571M/571M [00:03<00:00, 158MB/s]

# %%
! rm -rf /content/__MACOSX
! rm -rf /content/uw_sem_seg_dataset.zip

# %%
! gdown https://drive.google.com/uc?id=1B4Xh2rhIGe8oMQtOd2znNsc3oIb32lu8
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1B4Xh2rhIGe8oMQtOd2znNsc3oIb32lu8
# To: /content/hrnetv2_w48_imagenet_pretrained.pth
# 100% 311M/311M [00:06<00:00, 51.6MB/s]

# %%
! rm -rf /content/HRNetV2

# %%
import gdown

gdown.download_folder('https://drive.google.com/drive/folders/1ZJwKB-mRODYg1Lvk337pV-MZks0zMPfG')
# Out:
# Retrieving folder list
# Processing file 1_bp5iUMXD56pd6J57Rx-thAR25F-95qS best_new.pth
# Processing file 1zAnWerb9c69Ac_XKR3ZJINrgVMZgawig best.pth
# Building directory structure completed
# Retrieving folder list completed
# Building directory structure
# Downloading...
# From: https://drive.google.com/uc?id=1_bp5iUMXD56pd6J57Rx-thAR25F-95qS
# To: /content/HRNetV2/best_new.pth
# 100%|██████████| 264M/264M [00:20<00:00, 13.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1zAnWerb9c69Ac_XKR3ZJINrgVMZgawig
# To: /content/HRNetV2/best.pth
# 100%|██████████| 264M/264M [00:03<00:00, 69.1MB/s]
# Download completed
# ['/content/HRNetV2/best_new.pth', '/content/HRNetV2/best.pth']

# %%
! pip install imagecodecs
! pip install pickle5
! pip install timm
! pip install tensorboardX
! pip install yacs
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255330 sha256=8b6a610d8403ec7b9f05bf4db9e3402424fa9a7403445bfca687c525dda67338
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 36.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 37.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.5/304.5 kB 14.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
# ...

# %%
# !mkdir -p log
# !mkdir -p output

# %%
![[ -d ./uwsnet ]] && rm -rf ./uwsnet
# !git clone https://github.com/Imran2205/uwsnet
# Out:
# Cloning into 'uwsnet'...
# remote: Enumerating objects: 1247, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 1247 (delta 102), reused 86 (delta 46), pack-reused 1098
# Receiving objects: 100% (1247/1247), 1.67 MiB | 14.60 MiB/s, done.
# Resolving deltas: 100% (865/865), done.

# %%
! find ./uw_sem_seg_dataset -name "._*" -delete

# %%
# !python3 ./uwsnet/tools/test_hrnet_v2.py \
    --cfg ./uwsnet/experiments/hrnet/uws_training_hrnet_v2_test.yaml
# Out:
# Seeding with 304
# => creating /content/output/UWS3/uws_training_hrnet_v2_test
# => creating /content/log/UWS3/seg_hrnet/uws_training_hrnet_v2_test_2023-07-25-12-43
# Namespace(cfg='./uwsnet/experiments/hrnet/uws_training_hrnet_v2_test.yaml', seed=304, opts=[])
# AUTO_RESUME: False
# CUDNN:
#   BENCHMARK: True
#   DETERMINISTIC: False
#   ENABLED: True
# DATASET:
#   DATASET: UWS3
#   EXTRA_TRAIN_SET:
#   NUM_CLASSES: 29
#   ROOT: /content/uw_sem_seg_dataset
#   TEST_SET: validation
#   TRAIN_SET: train
# DEBUG:
#   DEBUG: False
#   SAVE_BATCH_IMAGES_GT: False
#   SAVE_BATCH_IMAGES_PRED: False
#   SAVE_HEATMAPS_GT: False
#   SAVE_HEATMAPS_PRED: False
# GPUS: (0,)
# LOG_DIR: /content/log
# LOSS:
#   BALANCE_WEIGHTS: [1]
#   CLASS_BALANCE: False
#   OHEMKEEP: 131072
#   OHEMTHRES: 0.9
#   USE_OHEM: False
# MODEL:
#   ALIGN_CORNERS: False
#   EXTRA:
#     FINAL_CONV_KERNEL: 1
#     STAGE1:
#       BLOCK: BOTTLENECK
#       FUSE_METHOD: SUM
#       NUM_BLOCKS: [4]
# ...
