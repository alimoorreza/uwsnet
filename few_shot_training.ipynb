# %% [markdown]
# <a href="https://colab.research.google.com/github/Imran2205/uwsnet/blob/main/few_shot_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install gdown

# %%
![[ -d ./uwsnet ]] && rm -rf ./uwsnet
! git clone https://github.com/Imran2205/uwsnet
# Out:
# Cloning into 'uwsnet'...
# remote: Enumerating objects: 349, done.
# remote: Counting objects: 100% (349/349), done.
# remote: Compressing objects: 100% (193/193), done.
# remote: Total 349 (delta 166), reused 331 (delta 148), pack-reused 0
# Receiving objects: 100% (349/349), 1.48 MiB | 7.88 MiB/s, done.
# Resolving deltas: 100% (166/166), done.

# %%
# download fewshot dataset from google drive and extract it
! gdown https://drive.google.com/uc?id=14Qi3Zgb5ZL0oIsuZHDw5JmQxjOVGPtU4
! unzip -q uw_fewshot_dataset.zip
# ! rm -rf /content/uwsnet/dataset/*
# ! mv dataset/* /content/uwsnet/dataset
! rm -rf /content/__MACOSX
# ! rm -rf /content/dataset
! rm -rf /content/uw_fewshot_dataset.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=14Qi3Zgb5ZL0oIsuZHDw5JmQxjOVGPtU4
# To: /content/uw_fewshot_dataset.zip
# 100% 917M/917M [00:14<00:00, 62.7MB/s]

# %%
# download dataset splits
import gdown
gdown.download_folder('https://drive.google.com/drive/folders/1IOLhsgBd2ZnVr4I10s8m4PqfP2yzpEbp', quiet=True)
# Out:
# ['/content/dataset_split/classes2labels.joblib',
#  '/content/dataset_split/labels_split.joblib']

# %%
! rm -rf /content/uwsnet/dataset_split/*
! mv dataset_split/* /content/uwsnet/dataset_split
! rm -rf /content/dataset_split

# %%
# download backbones
gdown.download_folder('https://drive.google.com/drive/folders/15AD86KAKEpySFu8NFNZcPWE_9vmAuGx5', quiet=True)
# Out:
# ['/content/backbones/resnet50_v2.pth',
#  '/content/backbones/resnet101_v2.pth',
#  '/content/backbones/vgg16_bn.pth',
#  '/content/backbones/vgg16-397923af.pth']

# %%
! rm -rg lpg
! rm -rf output

# %%
! mkdir -p log
! mkdir -p output

# %%
! pip install imagecodecs
! pip install pickle5
! pip install timm
! pip install einops
! pip install pytorch_lightning
! pip install yacs
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=256385 sha256=afc5fb44a2b863bebc9e26cefbb56bfb77115420c277ace53a88bcbbbab86df8
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 52.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 16.0 MB/s eta 0:00:00
# ...

# %%
# Train UWSNet V2 for 1 shot with split 1 as validation set
! python3 ./uwsnet/tools/train.py \
    --config ./uwsnet/experiments/eca_net_sup_que_vgg16_config/1_shot/uw_few_shot_training_config_eca_net_sup_que_vgg16_shot_1_split_0.yaml

# Train UWSNet V2 for 1 shot with split 2 as validation set
# ! python3 ./uwsnet/tools/train.py \
#     --config ./uwsnet/experiments/eca_net_sup_que_vgg16_config/1_shot/uw_few_shot_training_config_eca_net_sup_que_vgg16_shot_1_split_1.yaml

# Train UWSNet V2 for 1 shot with split 3 as validation set
# ! python3 ./uwsnet/tools/train.py \
#     --config ./uwsnet/experiments/eca_net_sup_que_vgg16_config/1_shot/uw_few_shot_training_config_eca_net_sup_que_vgg16_shot_1_split_2.yaml

# Train UWSNet V2 for 1 shot with split 4 as validation set
# ! python3 ./uwsnet/tools/train.py \
#     --config ./uwsnet/experiments/eca_net_sup_que_vgg16_config/1_shot/uw_few_shot_training_config_eca_net_sup_que_vgg16_shot_1_split_3.yaml

# Train UWSNet V6 for 1 shot with split 1 as validation set
# ! python3 ./uwsnet/tools/train.py \
#     --config ./uwsnet/experiments/triplet_sup_que_vgg16_dice_config/1_shot/uw_few_shot_training_config_triplet_sup_que_vgg16_dice_shot_1_split_0.yaml

# Train UWSNet V6 for 1 shot with split 2 as validation set
# ! python3 ./uwsnet/tools/train.py \
#     --config ./uwsnet/experiments/triplet_sup_que_vgg16_dice_config/1_shot/uw_few_shot_training_config_triplet_sup_que_vgg16_dice_shot_1_split_1.yaml

# Train UWSNet V6 for 1 shot with split 3 as validation set
# ! python3 ./uwsnet/tools/train.py \
#     --config ./uwsnet/experiments/triplet_sup_que_vgg16_dice_config/1_shot/uw_few_shot_training_config_triplet_sup_que_vgg16_dice_shot_1_split_2.yaml

# Train UWSNet V6 for 1 shot with split 4 as validation set
# ! python3 ./uwsnet/tools/train.py \
#     --config ./uwsnet/experiments/triplet_sup_que_vgg16_dice_config/1_shot/uw_few_shot_training_config_triplet_sup_que_vgg16_dice_shot_1_split_3.yaml
# Out:
# 2023-07-10 17:15:22.742695: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-10 17:15:23.663564: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Using PyTorch version:  2.0.1+cu118
# PAnet model will be used ......
# total number of parameters:  14714702
# total number of trainable parameters:  14714702
# => creating /content/output/uw_few_shot_training_config_eca_net_sup_que_vgg16_shot_1_split_0
# => creating /content/log/PAnet/uw_few_shot_training_config_eca_net_sup_que_vgg16_shot_1_split_0_2023-07-10-17-15
# BASE_DIR: /content/uwsnet/
# CLASSES: 2
# CUDNN:
#   BENCHMARK: True
#   DETERMINISTIC: False
#   ENABLED: True
# DATASET:
#   IMAGE_H: 473
#   IMAGE_W: 473
# ...
